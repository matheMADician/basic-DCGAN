# %% [markdown]
# # 在 Google Colab 中运行 DCGAN on CelebA
#
# 使用 GitHub repo: https://github.com/matheMADician/basic-DCGAN

# %%
# 克隆 GitHub repo
# !git clone https://github.com/matheMADician/basic-DCGAN.git
# %cd basic-DCGAN

# %%
# 安装依赖
# !pip install torch torchvision tqdm tensorboard

# %%
# 上传 CelebA 数据集 zip 文件
from google.colab import files
uploaded = files.upload()  # 上传你的 celeba.zip 文件

# 假设上传的文件名为 'celeba.zip'，解压到 dataset/ 文件夹
# !unzip celeb_dataset.zip -d dataset/

# 如果文件名不同，替换上面的 'celeba.zip' 为实际文件名
# 例如: !unzip your_filename.zip -d dataset/

# %%
# 运行训练
# !python train.py
