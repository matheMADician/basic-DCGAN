# %% [markdown]
# # 在 Google Colab 中运行 DCGAN on CelebA
#
# 使用 GitHub repo: https://github.com/matheMADician/basic-DCGAN

# %%
# 克隆 GitHub repo
# !git clone https://github.com/matheMADician/basic-DCGAN.git
# %cd basic-DCGAN

# %%
# 安装依赖
# !pip install torch torchvision tqdm tensorboard

# %%
# 下载 CelebA 数据集
# 设置 Kaggle API（上传你的 kaggle.json）
from google.colab import files
files.upload()  # 上传 kaggle.json

# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# !kaggle datasets download -d jessicali9530/celeba-dataset -p dataset/
# !unzip dataset/celeba-dataset.zip -d dataset/

# %%
# 运行训练
# !python train.py
